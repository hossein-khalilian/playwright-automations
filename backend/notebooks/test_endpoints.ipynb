# %%
import httpx

# %%
base_url = "http://host.docker.internal:8000/"
payload = {
    "username": "arash",
    "password": "changethis"
}
headers = {
    "accept": "application/json",
    "Content-Type": "application/json"
}

login_response = httpx.post(f"{base_url}auth/login", json=payload, headers=headers)
login_data = login_response.json()
access_token = login_data["access_token"]

headers.update({"Authorization": f"Bearer {access_token}"})

me_response = httpx.get(f"{base_url}auth/me", headers=headers)

# print(me_response.json())
print(access_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJhcmFzaCIsImV4cCI6MTc2NTM0ODU0Mn0.SSzmOLQwJexdQM2iq6k9m503lS5mqFrnnJcvtYF8Rmo

# %%
httpx.get(f"{base_url}notebooklm/notebooks", headers=headers).json()
# Out:
# {'notebooks': [{'notebook_id': '0eeff7c9-7605-4c68-854f-00ddfcb459fe',
#    'notebook_url': 'https://notebooklm.google.com/notebook/0eeff7c9-7605-4c68-854f-00ddfcb459fe',
#    'created_at': '2025-12-03T07:44:29.555000'},
#   {'notebook_id': '22d6f489-23a5-4b53-af21-1ef64c256886',
#    'notebook_url': 'https://notebooklm.google.com/notebook/22d6f489-23a5-4b53-af21-1ef64c256886',
#    'created_at': '2025-12-03T07:44:14.612000'}]}

# %%
resp = httpx.get(f"{base_url}notebooklm/notebooks/0eeff7c9-7605-4c68-854f-00ddfcb459fe/sources", headers=headers, timeout=60)
resp.json()
# Out:
# {'status': 'success',
#  'message': 'Found 1 sources in notebook 0eeff7c9-7605-4c68-854f-00ddfcb459fe.',
#  'sources': [{'name': 'tmpc9vxhlx7.txt', 'status': 'ready'}]}
